# %%
import numpy as np
import pandas as pd
import sklearn.model_selection

# %%
#%ls "../processed_data/train_full.csv"
train_df = pd.read_csv("../processed_data/train_full.csv")
train_df.head()
# Out:
#    Unnamed: 0  Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley  \
# 0           1   1          60       rl           65     8450   pave  nothing
# 1           2   2          20       rl           80     9600   pave  nothing
# 2           3   3          60       rl           68    11250   pave  nothing
# 3           4   4          70       rl           60     9550   pave  nothing
# 4           5   5          60       rl           84    14260   pave  nothing
#
#   LotShape LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0      reg         lvl    allpub    inside       gtl      collgcr       norm
# 1      reg         lvl    allpub       fr2       gtl      veenker      feedr
# 2      ir1         lvl    allpub    inside       gtl      collgcr       norm
# 3      ir1         lvl    allpub    corner       gtl      crawfor       norm
# 4      ir1         lvl    allpub       fr2       gtl      noridge       norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       norm     1fam     2story            7            5       2003
# 1       norm     1fam     1story            6            8       1976
# 2       norm     1fam     2story            7            5       2001
# 3       norm     1fam     2story            7            5       1915
# 4       norm     1fam     2story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     gable  compshg     vinylsd     vinylsd    brkface
# 1          1976     gable  compshg     metalsd     metalsd    nothing
# 2          2002     gable  compshg     vinylsd     vinylsd    brkface
# 3          1970     gable  compshg     wd sdng     wd shng    nothing
# 4          2000     gable  compshg     vinylsd     vinylsd    brkface
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0         196        gd        ta      pconc       gd       ta           no
# 1           0        ta        ta     cblock       gd       ta           gd
# 2         162        gd        ta      pconc       gd       ta           mn
# 3           0        ta        ta     brktil       ta       gd           no
# 4         350        gd        ta      pconc       gd       ta           av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          glq         706          unf           0        150          856
# 1          alq         978          unf           0        284         1262
# 2          glq         486          unf           0        434          920
# 3          alq         216          unf           0        540          756
# 4          glq         655          unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    gasa        ex          y      sbrkr       856       854             0
# 1    gasa        ex          y      sbrkr      1262         0             0
# 2    gasa        ex          y      sbrkr       920       866             0
# 3    gasa        gd          y      sbrkr       961       756             0
# 4    gasa        ex          y      sbrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          gd             8        typ           0     nothing
# 1             1          ta             6        typ           1          ta
# 2             1          gd             6        typ           1          ta
# 3             1          gd             7        typ           1          gd
# 4             1          gd             9        typ           1          ta
#
#   GarageType GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     attchd        2003          rfn           2         548         ta
# 1     attchd        1976          rfn           2         460         ta
# 2     attchd        2001          rfn           2         608         ta
# 3     detchd        1998          unf           3         642         ta
# 4     attchd        2000          rfn           3         836         ta
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         ta          y           0           61              0          0
# 1         ta          y         298            0              0          0
# 2         ta          y           0           42              0          0
# 3         ta          y           0           35            272          0
# 4         ta          y         192           84              0          0
#
#    ScreenPorch  PoolArea   PoolQC    Fence MiscFeature  MiscVal  MoSold  \
# 0            0         0  nothing  nothing     nothing        0       2
# 1            0         0  nothing  nothing     nothing        0       5
# 2            0         0  nothing  nothing     nothing        0       9
# 3            0         0  nothing  nothing     nothing        0       2
# 4            0         0  nothing  nothing     nothing        0      12
#
#    YrSold SaleType SaleCondition  SalePrice
# 0    2008       wd        normal     208500
# 1    2007       wd        normal     181500
# 2    2008       wd        normal     223500
# 3    2006       wd       abnorml     140000
# 4    2008       wd        normal     250000

# %%
sum(train_df.isnull().sum() > 0)
# Out:
# 0

# %%
train_df = df.drop(['Unnamed: 0', 'Id'], axis=1)

# %%
pd.set_option('display.max_columns',100)
train_df.head(1)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0          60       rl           65     8450   pave  nothing      reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         lvl    allpub    inside       gtl      collgcr       norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       norm     1fam     2story            7            5       2003
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     gable  compshg     vinylsd     vinylsd    brkface
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0         196        gd        ta      pconc       gd       ta           no
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          glq         706          unf           0        150          856
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    gasa        ex          y      sbrkr       856       854             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          gd             8        typ           0     nothing
#
#   GarageType GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     attchd        2003          rfn           2         548         ta
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         ta          y           0           61              0          0
#
#    ScreenPorch  PoolArea   PoolQC    Fence MiscFeature  MiscVal  MoSold  \
# 0            0         0  nothing  nothing     nothing        0       2
#
#    YrSold SaleType SaleCondition  SalePrice
# 0    2008       wd        normal     208500

# %%
train_df.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    57.623288   10516.828082     6.099315     5.575342
# std      42.300571    34.664304    9981.264932     1.382997     1.112799
# min      20.000000     0.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    42.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    63.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    79.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  \
# count  1460.000000   1460.000000  1460.000000  1460.000000  1460.000000
# mean   1971.267808   1984.865753   103.117123   443.639726    46.549315
# std      30.202904     20.645407   180.731373   456.098091   161.319273
# min    1872.000000   1950.000000     0.000000     0.000000     0.000000
# 25%    1954.000000   1967.000000     0.000000     0.000000     0.000000
# 50%    1973.000000   1994.000000     0.000000   383.500000     0.000000
# 75%    2000.000000   2004.000000   164.250000   712.250000     0.000000
# max    2010.000000   2010.000000  1600.000000  5644.000000  1474.000000
#
#          BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF  LowQualFinSF  \
# count  1460.000000  1460.000000  1460.000000  1460.000000   1460.000000
# mean    567.240411  1057.429452  1162.626712   346.992466      5.844521
# std     441.866955   438.705324   386.587738   436.528436     48.623081
# min       0.000000     0.000000   334.000000     0.000000      0.000000
# 25%     223.000000   795.750000   882.000000     0.000000      0.000000
# 50%     477.500000   991.500000  1087.000000     0.000000      0.000000
# 75%     808.000000  1298.250000  1391.250000   728.000000      0.000000
# max    2336.000000  6110.000000  4692.000000  2065.000000    572.000000
#
#          GrLivArea  BsmtFullBath  BsmtHalfBath     FullBath     HalfBath  \
# count  1460.000000   1460.000000   1460.000000  1460.000000  1460.000000
# mean   1515.463699      0.425342      0.057534     1.565068     0.382877
# std     525.480383      0.518911      0.238753     0.550916     0.502885
# min     334.000000      0.000000      0.000000     0.000000     0.000000
# 25%    1129.500000      0.000000      0.000000     1.000000     0.000000
# 50%    1464.000000      0.000000      0.000000     2.000000     0.000000
# 75%    1776.750000      1.000000      0.000000     2.000000     1.000000
# max    5642.000000      3.000000      2.000000     3.000000     2.000000
#
#        BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd   Fireplaces   GarageCars  \
# count   1460.000000   1460.000000   1460.000000  1460.000000  1460.000000
# mean       2.866438      1.046575      6.517808     0.613014     1.767123
# std        0.815778      0.220338      1.625393     0.644666     0.747315
# min        0.000000      0.000000      2.000000     0.000000     0.000000
# 25%        2.000000      1.000000      5.000000     0.000000     1.000000
# 50%        3.000000      1.000000      6.000000     1.000000     2.000000
# 75%        3.000000      1.000000      7.000000     1.000000     2.000000
# max        8.000000      3.000000     14.000000     3.000000     4.000000
#
#         GarageArea   WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  \
# count  1460.000000  1460.000000  1460.000000    1460.000000  1460.000000
# mean    472.980137    94.244521    46.660274      21.954110     3.409589
# std     213.804841   125.338794    66.256028      61.119149    29.317331
# min       0.000000     0.000000     0.000000       0.000000     0.000000
# 25%     334.500000     0.000000     0.000000       0.000000     0.000000
# 50%     480.000000     0.000000    25.000000       0.000000     0.000000
# 75%     576.000000   168.000000    68.000000       0.000000     0.000000
# max    1418.000000   857.000000   547.000000     552.000000   508.000000
#
#        ScreenPorch     PoolArea       MiscVal       MoSold       YrSold  \
# count  1460.000000  1460.000000   1460.000000  1460.000000  1460.000000
# mean     15.060959     2.758904     43.489041     6.321918  2007.815753
# std      55.757415    40.177307    496.123024     2.703626     1.328095
# min       0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%       0.000000     0.000000      0.000000     5.000000  2007.000000
# 50%       0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%       0.000000     0.000000      0.000000     8.000000  2009.000000
# max     480.000000   738.000000  15500.000000    12.000000  2010.000000
#
#            SalePrice
# count    1460.000000
# mean   180921.195890
# std     79442.502883
# min     34900.000000
# 25%    129975.000000
# 50%    163000.000000
# 75%    214000.000000
# max    755000.000000

# %%
train_df['SalePrice'].plot(kind='hist',figsize=(10,5)).plot()
# Out:
# []

# %%
train_df['SalePrice'].plot(kind='box').plot()
# Out:
# []

# %%
train_df['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
print(train_df.shape)
outlier_mask = train_df['SalePrice'] > (214000 - 129975) * 1.5
train_df[outlier_mask].shape
# Out:
# (1460, 80)
# (1142, 80)

# %%
import math

math.exp

# %%
from math import log
from math import exp

# %%
train_df['SalePrice'].map(lambda x: log(x)).plot(kind = 'hist').plot()
# Out:
# []

# %%
train_df['LogSalePrice'] = train_df['SalePrice'].map(lambda x: log(x))

# %%
#train_df.head(1)

train_df[['SalePrice','LogSalePrice']].head()
# Out:
#    SalePrice  LogSalePrice
# 0     208500     12.247694
# 1     181500     12.109011
# 2     223500     12.317167
# 3     140000     11.849398
# 4     250000     12.429216

# %%
train_df['LogSalePrice'].describe()
# Out:
# count    1460.000000
# mean       12.024051
# std         0.399452
# min        10.460242
# 25%        11.775097
# 50%        12.001505
# 75%        12.273731
# max        13.534473
# Name: LogSalePrice, dtype: float64

# %%
print(train_df.shape)
outlier_mask = train_df['LogSalePrice'] > (12.273731 - 11.775097) * 1.5
train_df[outlier_mask].shape
# Out:
# (1460, 81)
# (1460, 81)

# %%
train_df['LogSalePrice'].map(lambda x: log(x)).plot(kind = 'box').plot()
# Out:
# []

# %%
#[column for column in train_df.columns.tolist() if column not in ['YearBuilt']]

# %%
corr = train_df.corr()
#corr2 = train_df.loc[:,[column for column in train_df.columns.tolist() if column not in \
  #                  ['YearBuilt','OverallQual','TotRmsAbvGrd','GarageCars']]].corr() 
#pd.set_option('display.max_rows',1100)
corr2.head()
# Out:
#               MSSubClass  LotFrontage   LotArea  OverallCond  YearRemodAdd  \
# MSSubClass      1.000000    -0.215023 -0.139781    -0.059316      0.040581
# LotFrontage    -0.215023     1.000000  0.100739    -0.053457      0.078686
# LotArea        -0.139781     0.100739  1.000000    -0.005636      0.013788
# OverallCond    -0.059316    -0.053457 -0.005636     1.000000      0.073741
# YearRemodAdd    0.040581     0.078686  0.013788     0.073741      1.000000
#
#               MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# MSSubClass      0.023573   -0.069836   -0.065649  -0.140759    -0.238518
# LotFrontage     0.105010    0.076670   -0.009312   0.160829     0.238274
# LotArea         0.103321    0.214103    0.111170  -0.002618     0.260833
# OverallCond    -0.125694   -0.046231    0.040229  -0.136841    -0.171098
# YearRemodAdd    0.176529    0.128451   -0.067759   0.181133     0.291066
#
#               1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  \
# MSSubClass   -0.251758  0.307886      0.046474   0.074853      0.003491
# LotFrontage   0.245181  0.042549      0.049981   0.220347      0.010514
# LotArea       0.299475  0.050986      0.004779   0.263116      0.158155
# OverallCond  -0.144203  0.028942      0.025494  -0.079686     -0.054942
# YearRemodAdd  0.240379  0.140024     -0.062419   0.287389      0.119470
#
#               BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# MSSubClass       -0.002333  0.131608  0.177354     -0.023438      0.281721
# LotFrontage      -0.027856  0.120548 -0.012952      0.144494      0.034425
# LotArea           0.048046  0.126031  0.014259      0.119690     -0.017784
# OverallCond       0.117821 -0.194149 -0.060769      0.012980     -0.087001
# YearRemodAdd     -0.012337  0.439046  0.183331     -0.040581     -0.149598
#
#               Fireplaces  GarageArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# MSSubClass     -0.045569   -0.098672   -0.012579    -0.006100      -0.012037
# LotFrontage     0.044018    0.201473   -0.016780     0.069605       0.027366
# LotArea         0.271364    0.180403    0.171698     0.084774      -0.018340
# OverallCond    -0.023820   -0.151521   -0.003334    -0.032589       0.070356
# YearRemodAdd    0.112581    0.371600    0.205726     0.226298      -0.193919
#
#               3SsnPorch  ScreenPorch  PoolArea   MiscVal    MoSold    YrSold  \
# MSSubClass    -0.043825    -0.026030  0.008283 -0.007683 -0.013585 -0.021407
# LotFrontage    0.023499     0.022969  0.114106 -0.059606  0.018942 -0.012094
# LotArea        0.020423     0.043160  0.077672  0.038068  0.001205 -0.014261
# OverallCond    0.025504     0.054811 -0.001985  0.068777 -0.003511  0.043950
# YearRemodAdd   0.045286    -0.038740  0.005829 -0.010286  0.021490  0.035743
#
#               SalePrice  LogSalePrice
# MSSubClass    -0.084284     -0.073959
# LotFrontage    0.209624      0.179303
# LotArea        0.263843      0.257320
# OverallCond   -0.077856     -0.036868
# YearRemodAdd   0.507101      0.565608

# %% [markdown]
# Here are columns I suggest to be removed:
# -YearBuilt:  This columns correlates with many columsn in the dataset. Additionally I do not think the YearBuilt influences the price but the quality of the house
# -YearRemodAdd: This is the same with YearBuilt
# -

# %%
#corr.style.background_gradient(cmap='coolwarm').set_precision(2)
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col3 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col4 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col5 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col6 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col7 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col8 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col9 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col10 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col13 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col14 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col15 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col16 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col17 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col18 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col19 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col20 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col21 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col22 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col23 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col24 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col25 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col26 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col27 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col28 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col29 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col30 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col31 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col32 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col33 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col34 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col35 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row0_col36 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row1_col0 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row1_col2 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row1_col3 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row1_col4 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row1_col5 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row1_col6 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row1_col7 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row1_col8 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row1_col9 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row1_col10 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row1_col11 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row1_col12 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row1_col13 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row1_col14 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row1_col15 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row1_col16 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row1_col17 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row1_col18 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row1_col19 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row1_col20 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row1_col21 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_082c7a86_9d3a_11ea_8d2b_bc8385cdada1row1_col22 {
#             background-color:  #

# %%
np.isreal(s)

s = np.arange(3)

# %%
np.isreal(s)!=True
# Out:
# array([False, False, False])

# %%
train_df.shape
# Out:
# (1460, 81)

# %%
sum(train_df['YearBuilt'] < 1920)
# Out:
# 88

# %%
train_df['YearBuilt'].map(lambda x: group1 x < 1920 if  )


year_break(x):
    if x < 1920:
        'group1'
    else:
        x
# Out:
# 6.027397260273973

# %%
def year_to_group2(year):
    if year < 1920:
        return 1
    elif year > 1999:
        return 10
    else:
        return int(list(str(year))[2])

# %%
def year_to_group(year):
    decade = list(str(year))[2]
    if year < 1920:
        return 'group_1'
    elif int(decade) == 0:
        return 'group_'+ '10'
    elif :
        return 'group' + list('year')[2]
# Out:
#   File "<ipython-input-213-84d6c21c8f30>", line 7
#     elif :
#          ^
# SyntaxError: invalid syntax

# %%
train_df['YearBuilt'].map(year_to_group2).unique()
# Out:
# array([10,  7,  1,  9,  3,  6,  2,  5,  8,  4], dtype=int64)

# %%
train_df['OrdYearBuilt'] = train_df['YearBuilt'].map(year_to_group2)

# %%
train_df.OrdYearBuilt
# Out:
# 0       10
# 1        7
# 2       10
# 3        1
# 4       10
# 5        9
# 6       10
# 7        7
# 8        3
# 9        3
# 10       6
# 11      10
# 12       6
# 13      10
# 14       6
# 15       2
# 16       7
# 17       6
# 18      10
# 19       5
# 20      10
# 21       3
# 22      10
# 23       7
# 24       6
# 25      10
# 26       5
# 27      10
# 28       5
# 29       2
# 30       2
# 31       6
# 32      10
# 33       5
# 34      10
# 35      10
# 36       9
# 37       5
# 38       5
# 39       5
# 40       6
# 41       5
# 42       8
# 43       7
# 44       5
# 45      10
# 46      10
# 47      10
# 48       2
# 49       6
# 50       9
# 51       3
# 52       6
# 53       8
# 54       5
# 55       6
# 56       9
# 57      10
# 58      10
# 59       7
# 60      10
# 61       2
# 62      10
# 63       2
# 64       9
# 65      10
# 66       7
# 67      10
# 68       4
# 69       5
# 70       7
# 71       8
# 72       9
# 73       5
# 74       1
# 75       7
# 76       5
# 77       4
# 78       6
# 79       1
# 80       6
# 81       9
# 82      10
# 83       6
# 84       9
# 85       9
# 86      10
# 87      10
# 88       1
# 89       9
# 90       5
# 91       6
# 92       2
# 93       1
# 94       9
# 95       9
# 96       9
# 97       6
# 98       2
# 99       5
# 100      7
# 101      8
# 102      7
# 103     10
# 104      3
# 105     10
# 106      1
# 107      4
# 108      1
# 109      7
# 110      5
# 111     10
# 112     10
# 113      5
# 114      4
# 115      9
# 116      6
# 117     10
# 118      9
# 119     10
# 120      6
# 121      3
# 122      5
# 123      9
# 124      7
# 125      3
# 126      7
# 127      3
# 128      6
# 129      5
# 130      6
# 131     10
# 132      5
# 133     10
# 134      6
# 135      7
# 136      6
# 137      8
# 138      9
# 139      9
# 140      7
# 141     10
# 142      5
# 143      9
# 144      6
# 145     10
# 146      3
# 147     10
# 148     10
# 149      3
# 150      7
# 151     10
# 152      7
# 153      6
# 154      2
# 155      2
# 156      5
# 157     10
# 158     10
# 159     10
# 160      8
# 161     10
# 162     10
# 163      5
# 164      2
# 165      4
# 166      5
# 167     10
# 168     10
# 169      8
# 170      4
# 171      6
# 172      8
# 173      6
# 174      8
# 175      5
# 176      8
# 177      5
# 178     10
# 179      2
# 180     10
# 181      2
# 182      5
# 183     10
# 184      1
# 185      1
# 186      9
# 187      1
# 188      7
# 189     10
# 190      3
# 191      7
# 192      9
# 193     10
# 194      7
# 195      7
# 196     10
# 197      1
# 198      1
# 199     10
# 200     10
# 201      7
# 202      2
# 203     10
# 204      4
# 205      9
# 206      6
# 207      6
# 208      8
# 209      6
# 210      2
# 211     10
# 212     10
# 213      9
# 214      7
# 215      5
# 216     10
# 217      2
# 218      3
# 219     10
# 220     10
# 221     10
# 222      7
# 223      7
# 224     10
# 225      7
# 226      9
# 227      7
# 228      6
# 229     10
# 230      5
# 231      9
# 232      7
# 233      7
# 234     10
# 235      7
# 236     10
# 237      9
# 238     10
# 239      4
# 240     10
# 241      4
# 242      1
# 243      8
# 244      9
# 245      8
# 246      1
# 247      5
# 248     10
# 249      5
# 250      4
# 251     10
# 252     10
# 253      6
# 254      5
# 255      9
# 256     10
# 257     10
# 258     10
# 259      5
# 260      6
# 261     10
# 262      7
# 263      2
# 264      2
# 265      8
# 266      9
# 267      3
# 268      4
# 269      7
# 270     10
# 271      5
# 272      9
# 273      5
# 274      8
# 275      2
# 276     10
# 277      5
# 278     10
# 279      7
# 280      8
# 281     10
# 282     10
# 283     10
# 284      9
# 285     10
# 286      6
# 287      7
# 288      6
# 289      1
# 290     10
# 291      1
# 292      4
# 293      7
# 294      5
# 295      8
# 296      5
# 297      9
# 298      6
# 299      5
# 300      5
# 301      9
# 302     10
# 303      7
# 304      1
# 305     10
# 306      9
# 307      2
# 308      4
# 309     10
# 310      9
# 311      4
# 312      3
# 313      6
# 314      2
# 315     10
# 316      8
# 317     10
# 318      9
# 319      8
# 320     10
# 321     10
# 322      8
# 323      5
# 324      6
# 325      4
# 326      9
# 327      6
# 328      1
# 329      2
# 330      6
# 331      5
# 332     10
# 333     10
# 334      9
# 335      6
# 336     10
# 337     10
# 338      8
# 339      5
# 340     10
# 341      5
# 342      4
# 343     10
# 344      7
# 345      3
# 346      6
# 347      6
# 348     10
# 349     10
# 350     10
# 351      8
# 352      4
# 353      2
# 354      4
# 355      9
# 356      9
# 357      7
# 358      5
# 359      9
# 360      7
# 361      4
# 362     10
# 363      7
# 364      7
# 365      2
# 366      6
# 367      6
# 368      5
# 369      5
# 370     10
# 371      5
# 372      8
# 373      5
# 374     10
# 375      2
# 376      9
# 377     10
# 378     10
# 379     10
# 380      2
# 381     10
# 382     10
# 383      2
# 384      9
# 385     10
# 386      1
# 387      7
# 388      9
# 389     10
# 390      1
# 391     10
# 392      5
# 393      4
# 394      4
# 395      5
# 396      7
# 397      6
# 398      2
# 399     10
# 400      9
# 401     10
# 402      4
# 403      9
# 404      9
# 405      7
# 406      3
# 407      1
# 408     10
# 409     10
# 410      5
# 411      5
# 412     10
# 413      2
# 414      9
# 415     10
# 416      7
# 417      1
# 418      4
# 419      6
# 420      9
# 421      7
# 422      5
# 423      9
# 424      5
# 425      4
# 426      8
# 427      5
# 428     10
# 429      8
# 430      7
# 431      2
# 432      7
# 433      9
# 434      7
# 435      9
# 436      2
# 437      2
# 438      1
# 439      2
# 440     10
# 441      5
# 442      3
# 443     10
# 444      9
# 445      5
# 446      6
# 447      9
# 448      3
# 449      4
# 450      3
# 451      7
# 452      9
# 453     10
# 454      7
# 455      7
# 456      1
# 457      5
# 458      2
# 459      5
# 460     10
# 461      3
# 462      6
# 463      3
# 464      7
# 465     10
# 466      7
# 467      4
# 468     10
# 469      9
# 470      8
# 471      7
# 472     10
# 473     10
# 474     10
# 475      6
# 476      9
# 477     10
# 478     10
# 479      3
# 480     10
# 481     10
# 482      1
# 483      9
# 484      6
# 485      5
# 486      6
# 487      7
# 488      1
# 489      7
# 490      7
# 491      4
# 492     10
# 493      6
# 494      3
# 495      2
# 496      9
# 497      2
# 498      6
# 499      5
# 500      7
# 501     10
# 502      6
# 503      5
# 504      7
# 505      5
# 506      9
# 507     10
# 508      2
# 509      5
# 510      5
# 511     10
# 512      5
# 513      8
# 514      2
# 515     10
# 516      7
# 517      9
# 518      9
# 519      2
# 520      1
# 521      5
# 522      4
# 523     10
# 524      9
# 525     10
# 526      5
# 527     10
# 528      2
# 529      5
# 530      8
# 531      2
# 532      5
# 533      4
# 534     10
# 535      1
# 536      9
# 537      7
# 538      6
# 539     10
# 540     10
# 541     10
# 542      9
# 543      9
# 544     10
# 545      8
# 546      2
# 547      7
# 548      5
# 549     10
#         ..
# 910      6
# 911      7
# 912      2
# 913      4
# 914     10
# 915      7
# 916      4
# 917      5
# 918      9
# 919      5
# 920      9
# 921      1
# 922     10
# 923      9
# 924      8
# 925      7
# 926     10
# 927      6
# 928     10
# 929      9
# 930     10
# 931      6
# 932     10
# 933     10
# 934      6
# 935      2
# 936     10
# 937     10
# 938     10
# 939      4
# 940      7
# 941      9
# 942      7
# 943      6
# 944      5
# 945      1
# 946      5
# 947     10
# 948     10
# 949      7
# 950      5
# 951      6
# 952      7
# 953      6
# 954      7
# 955      4
# 956      8
# 957      6
# 958     10
# 959      9
# 960      5
# 961      7
# 962      7
# 963     10
# 964     10
# 965     10
# 966      4
# 967      5
# 968      1
# 969      5
# 970      4
# 971     10
# 972      7
# 973     10
# 974      1
# 1418     6
# 1419     6
# 1420     6
# 1421     7
# 1422    10
# 1423     6
# 1424     5
# 1425     5
# 1426     9
# 1427     4
# 1428     4
# 1429     8
# 1430    10
# 1431     7
# 1432     2
# 1433    10
# 1434     7
# 1435     6
# 1436     7
# 1437    10
# 1438     5
# 1439     7
# 1440     2
# 1441    10
# 1442    10
# 1443     1
# 1444    10
# 1445     6
# 1446     6
# 1447     9
# 1448     1
# 1449     7
# 1450     7
# 1451    10
# 1452    10
# 1453    10
# 1454    10
# 1455     9
# 1456     7
# 1457     4
# 1458     5
# 1459     6
# Name: OrdYearBuilt, Length: 1460, dtype: int64

# %%
train_df.groupby('OrdYearBuilt').agg('mean').plot(y='LogSalePrice',kind='bar', title = 'Ord Year vs Median LogSalePrice')
train_df.groupby('OrdYearBuilt').agg('mean').plot(y='SalePrice',kind='bar', title = 'OrdYear vs Mean Sale Price')

# %%
import seaborn as sns
import matplotlib as plt

# %%
#grp = train_df.groupby('OrdYearBuilt')
sns.boxplot(y=train_df.SalePrice, x =train_df.OrdYearBuilt);

# %%
train_df.groupby('OrdYearBuilt').plot(x ='OrdYearBuilt', y='SalePrice', kind='box').plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-252-870e1eb09451> in <module>
# ----> 1 train_df.groupby('OrdYearBuilt').plot(x ='OrdYearBuilt', y='SalePrice', kind='box').plot()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2740                            colormap=colormap, table=table, yerr=yerr,
#    2741                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2742                            **kwds)
#    2743     __call__.__doc__ = plot_series.__doc__
#    2744
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    1996                  yerr=yerr, xerr=xerr,
#    1997                  label=label, secondary_y=secondary_y,
# -> 1998                  **kwds)
#    1999
#    2000
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1799         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1800
# -> 1801     plot_obj.generate()
#    1802     plot_obj.draw()
#    1803     return plot_obj.result
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     247     def generate(self):
#     248         self._args_adjust()
# --> 249         self._compute_plot_data()
#     250         self._setup_subplots()
#     251         self._make_plot()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _compute_plot_data(self)
#     365         if is_empty:
#     366             raise TypeError('Empty {0!r}: no numeric data to '
# --> 367                             'plot'.format(numeric_data.__class__.__name__))
#     368
#     369         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %%
train_df['YrSold'].unique()
# Out:
# array([2008, 2007, 2006, 2009, 2010], dtype=int64)

# %%
train_df.groupby('YrSold').agg('mean').plot(y='SalePrice',kind='bar') #.plot()

# %%
train_df.?
# Out:
#   File "<ipython-input-333-974b4b29ca86>", line 1
#     train_df.?
#              ^
# SyntaxError: invalid syntax

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
x_train, x_test = train_test_split(train_df)

# %%
x_train.shape, x_test.shape
# Out:
# ((1095, 82), (365, 82))

# %%
#x_train.SalePrice.unique()

# %%
y_train = x_train[['SalePrice','LogSalePrice']]

# %%
#x_train.loc[:, x_train.columns != 'SalePrice']

x_train = x_train.drop(['LogSalePrice', 'SalePrice','YearBuilt','Utilities','GarageYrBlt','GarageCars',\
              'PoolQC','GarageCond','YrSold','YearRemodAdd'], axis = 1)

# %%
rf_model = RandomForestClassifier()

# %%
rf_model.fit(x_train,y_train['SalePrice'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-328-0f88550cfa01> in <module>
# ----> 1 rf_model.fit(x_train,y_train['SalePrice'])
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     248
#     249         # Validate or convert input data
# --> 250         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     251         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     252         if sample_weight is not None:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     525             try:
#     526                 warnings.simplefilter('error', ComplexWarning)
# --> 527                 array = np.asarray(array, dtype=dtype, order=order)
#     528             except ComplexWarning:
#     529                 raise ValueError("Complex data not supported\n"
#
# ~\Anaconda3\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ValueError: could not convert string to float: 'rl'
